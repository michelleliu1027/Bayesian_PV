# %% [markdown]
# ## Spline Regression Auto-Loop

# %%
#import package
from scipy.interpolate import interp1d
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from scipy import interpolate

# %%
#import normal data - 120 C, time:0~5000s
address = 'data/degradation.xlsx'
x = []
y = []
df = pd.read_excel(address,sheet_name = 'normal data',usecols = [0],names = None,nrows = 5000)
df_li_Time = df.values.tolist()
df = pd.read_excel(address,sheet_name = 'normal data',usecols = [3],names = None,nrows = 5000)
df_li_L = df.values.tolist()

# %%
x = np.array(df_li_Time).T
y = np.array(df_li_L).T 
x = x.reshape((5000))
y = y.reshape((5000))
tck = interpolate.splrep(x, y, s=0)
x_cubic = np.arange(0,5000,100)
y_cubic = interpolate.splev(x_cubic,tck, der=0)

# %%
plt.figure()
plt.plot(x, y, 'x', x_cubic, y_cubic, '-')
plt.legend(['data','cubic spline'])
plt.tick_params(axis='y', colors = 'white')
plt.tick_params(axis='x', colors = 'white')
plt.show()

# %%
s = interpolate.InterpolatedUnivariateSpline(x, y)
x_uni = np.arange(0,5000,100)
y_uni = s(x_uni)

# %%
plt.figure()
plt.plot(x, y, 'x',x_uni,y_uni, x_cubic, y_cubic,'b')
plt.legend(['data','univariateSpline','cubic spline'])
plt.tick_params(axis='y', colors = 'white')
plt.tick_params(axis='x', colors = 'white')
plt.show()

# %%
#loop residuals<0.1 then stop

# %%
address = 'data/degradation.xlsx'
x = []
y = []
df = pd.read_excel(address,sheet_name = 'C1',usecols = [0],names = None)
df_li_Time = df.values.tolist()
df = pd.read_excel(address,sheet_name = 'C1',usecols = [3],names = None)
df_li_L = df.values.tolist()

# %%
x = np.array(df_li_Time).T
y = np.array(df_li_L).T 
x = x.reshape((14))
y = y.reshape((14))
tck = interpolate.splrep(x, y, s=0)
x_cubic = np.arange(0,5000,100)
y_cubic = interpolate.splev(x_cubic,tck, der=0)
print(x)
# Out:
# [   0  100  142  271  372  432  469  551 1000 1538 2000 3000 4000 5000]

# %%
plt.figure()
plt.plot(x, y, 'x', x_cubic, y_cubic, '-')
plt.legend(['data','cubic spline'])
plt.tick_params(axis='y', colors = 'white')
plt.tick_params(axis='x', colors = 'white')
plt.show()

# %%
s = interpolate.InterpolatedUnivariateSpline(x, y)
x_uni = np.arange(0,5000,1)
y_uni = s(x_uni)

# %%
plt.figure()
plt.plot(x, y, 'x',x_uni,y_uni,'-')
plt.legend(['data','univariateSpline'])
plt.tick_params(axis='y', colors = 'white')
plt.tick_params(axis='x', colors = 'white')
plt.show()

# %%
yder = interpolate.splev(x_uni, tck, der=1)
plt.figure()
plt.plot(x_uni, yder,'--')
plt.legend(['Cubic Spline'])
plt.title('Derivative estimation from spline')
plt.tick_params(axis='y', colors = 'white')
plt.tick_params(axis='x', colors = 'white')
plt.show()

# %%
list_y_uni = y_uni .tolist()
 
list_y_uni_max_list = min(list_y_uni) #get the maxium value
y_uni_index = list_y_uni.index(min(list_y_uni)) # get the index of maxium value
print(y_uni_index)
# Out:
# 154

# %%
x = []
y = []
df = pd.read_excel(address,sheet_name = 'C1',usecols = [0],names = None)
df_li_Time = df.values.tolist()
df = pd.read_excel(address,sheet_name = 'C1',usecols = [3],names = None)
df_li_L = df.values.tolist()

# %%
x = np.array(df_li_Time).T
y = np.array(df_li_L).T 
x = x.reshape((14))
y = y.reshape((14))
s = interpolate.InterpolatedUnivariateSpline(x, y)
x_uni = np.arange(0,5000,1)
y_uni = s(x_uni)

# %%
plt.figure()
plt.plot(x, y, 'x',x_uni,y_uni,'-')
plt.legend(['data','univariateSpline'])
plt.tick_params(axis='y', colors = 'white')
plt.tick_params(axis='x', colors = 'white')
plt.show()

# %%
list_y_uni = y_uni .tolist()
 
list_y_uni_max_list = min(list_y_uni) #get the maxium value
y_uni_index = list_y_uni.index(min(list_y_uni)) # get the index of maxium value
print(y_uni_index)
# Out:
# 154

# %%
x = []
y = []
df = pd.read_excel(address,sheet_name = 'C1',usecols = [0],names = None)
df_li_Time = df.values.tolist()
df = pd.read_excel(address,sheet_name = 'C1',usecols = [3],names = None)
df_li_L = df.values.tolist()

# %%
x = np.array(df_li_Time).T
y = np.array(df_li_L).T 
x = x.reshape((14))
y = y.reshape((14))
s = interpolate.InterpolatedUnivariateSpline(x, y)
x_uni = np.arange(0,5000,1)
y_uni = s(x_uni)
plt.figure()
plt.plot(x, y, 'x',x_uni,y_uni,'-')
plt.legend(['data','univariateSpline'])
plt.tick_params(axis='y', colors = 'white')
plt.tick_params(axis='x', colors = 'white')
plt.show()

# %%
list_y_uni = y_uni .tolist()
 
list_y_uni_max_list = min(list_y_uni) #get the maxium value
y_uni_index = list_y_uni.index(min(list_y_uni)) # get the index of maxium value
print(y_uni_index)
# Out:
# 154

# %%
x = []
y = []
df = pd.read_excel(address,sheet_name = 'C1',usecols = [0],names = None)
df_li_Time = df.values.tolist()
df = pd.read_excel(address,sheet_name = 'C1',usecols = [3],names = None)
df_li_L = df.values.tolist()

# %%
x = np.array(df_li_Time).T
y = np.array(df_li_L).T 
x = x.reshape((9))
y = y.reshape((9))
s = interpolate.InterpolatedUnivariateSpline(x, y)
x_uni = np.arange(0,5000,1)
y_uni = s(x_uni)
plt.figure()
plt.plot(x, y, 'x',x_uni,y_uni,'-')
plt.legend(['data','univariateSpline'])
plt.tick_params(axis='y', colors = 'white')
plt.tick_params(axis='x', colors = 'white')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_41884/600223989.py in <module>
#       1 x = np.array(df_li_Time).T
#       2 y = np.array(df_li_L).T
# ----> 3 x = x.reshape((9))
#       4 y = y.reshape((9))
#       5 s = interpolate.InterpolatedUnivariateSpline(x, y)
#
# ValueError: cannot reshape array of size 14 into shape (9,)

# %%
list_y_uni = y_uni .tolist()
 
list_y_uni_max_list = min(list_y_uni) #get the maxium value
y_uni_index = list_y_uni.index(min(list_y_uni)) # get the index of maxium value
print(y_uni_index)
# Out:
# 271

# %%
x = []
y = []
df = pd.read_excel(address,sheet_name = 'C1',usecols = [0],names = None)
df_li_Time = df.values.tolist()
df = pd.read_excel(address,sheet_name = 'C1',usecols = [3],names = None)
df_li_L = df.values.tolist()

# %%
x = np.array(df_li_Time).T
y = np.array(df_li_L).T 
x = x.reshape((10))
y = y.reshape((10))
s = interpolate.InterpolatedUnivariateSpline(x, y)
x_uni = np.arange(0,5000,1)
y_uni = s(x_uni)
plt.figure()
plt.plot(x, y, 'x',x_uni,y_uni,'-')
plt.legend(['data','univariateSpline'])
plt.tick_params(axis='y', colors = 'white')
plt.tick_params(axis='x', colors = 'white')
plt.show()

# %%
list_y_uni = y_uni .tolist()
 
list_y_uni_max_list = min(list_y_uni) #get the maxium value
y_uni_index = list_y_uni.index(min(list_y_uni)) # get the index of maxium value
print(y_uni_index)
# Out:
# 372

# %%
x = []
y = []
df = pd.read_excel(address,sheet_name = 'C1',usecols = [0],names = None)
df_li_Time = df.values.tolist()
df = pd.read_excel(address,sheet_name = 'C1',usecols = [3],names = None)
df_li_L = df.values.tolist()

# %%
x = np.array(df_li_Time).T
y = np.array(df_li_L).T 
x = x.reshape((11))
y = y.reshape((11))
s = interpolate.InterpolatedUnivariateSpline(x, y)
x_uni = np.arange(0,5000,1)
y_uni = s(x_uni)
plt.figure()
plt.plot(x, y, 'x',x_uni,y_uni,'-')
plt.legend(['data','univariateSpline'])
plt.tick_params(axis='y', colors = 'white')
plt.tick_params(axis='x', colors = 'white')
plt.show()

# %%
list_y_uni = y_uni .tolist()
 
list_y_uni_max_list = min(list_y_uni) #get the maxium value
y_uni_index = list_y_uni.index(min(list_y_uni)) # get the index of maxium value
print(y_uni_index)
# Out:
# 432

# %%
x = []
y = []
df = pd.read_excel(address,sheet_name = 'C1',usecols = [0],names = None)
df_li_Time = df.values.tolist()
df = pd.read_excel(address,sheet_name = 'C1',usecols = [3],names = None)
df_li_L = df.values.tolist()

# %%
x = np.array(df_li_Time).T
y = np.array(df_li_L).T 
x = x.reshape((12))
y = y.reshape((12))
s = interpolate.InterpolatedUnivariateSpline(x, y)
x_uni = np.arange(0,5000,1)
y_uni = s(x_uni)
plt.figure()
plt.plot(x, y, 'x',x_uni,y_uni,'-')
plt.legend(['data','univariateSpline'])
plt.tick_params(axis='y', colors = 'white')
plt.tick_params(axis='x', colors = 'white')
plt.show()

# %%
list_y_uni = y_uni .tolist()
 
list_y_uni_max_list = min(list_y_uni) #get the maxium value
y_uni_index = list_y_uni.index(min(list_y_uni)) # get the index of maxium value
print(y_uni_index)
# Out:
# 312

# %%
x = []
y = []
df = pd.read_excel(address,sheet_name = 'C1',usecols = [0],names = None)
df_li_Time = df.values.tolist()
df = pd.read_excel(address,sheet_name = 'C1',usecols = [3],names = None)
df_li_L = df.values.tolist()

# %%
x = np.array(df_li_Time).T
y = np.array(df_li_L).T 
x = x.reshape((13))
y = y.reshape((13))
s = interpolate.InterpolatedUnivariateSpline(x, y)
x_uni = np.arange(0,5000,1)
y_uni = s(x_uni)
plt.figure()
plt.plot(x, y, 'x',x_uni,y_uni,'-')
plt.legend(['data','univariateSpline'])
plt.tick_params(axis='y', colors = 'white')
plt.tick_params(axis='x', colors = 'white')
plt.show()

# %%
list_y_uni = y_uni .tolist()
 
list_y_uni_max_list = min(list_y_uni) #get the maxium value
y_uni_index = list_y_uni.index(min(list_y_uni)) # get the index of maxium value
print(y_uni_index)
# Out:
# 142

# %%
x = []
y = []
df = pd.read_excel(address,sheet_name = 'C1',usecols = [0],names = None)
df_li_Time = df.values.tolist()
df = pd.read_excel(address,sheet_name = 'C1',usecols = [3],names = None)
df_li_L = df.values.tolist()

# %%
x = np.array(df_li_Time).T
y = np.array(df_li_L).T 
x = x.reshape((14))
y = y.reshape((14))
s = interpolate.InterpolatedUnivariateSpline(x, y)
x_uni = np.arange(0,5000,1)
y_uni = s(x_uni)
plt.figure()
plt.plot(x, y, 'x',x_uni,y_uni,'-')
plt.legend(['data','univariateSpline'])
plt.tick_params(axis='y', colors = 'white')
plt.tick_params(axis='x', colors = 'white')
plt.show()

# %%
list_y_uni = y_uni .tolist()
 
list_y_uni_max_list = min(list_y_uni) #get the maxium value
y_uni_index = list_y_uni.index(min(list_y_uni)) # get the index of maxium value
print(y_uni_index)
# Out:
# 154

# %%
df = pd.read_excel(address,sheet_name = 'smooth data',usecols = [0],names = None,nrows = 5000)
df_li_Time_smooth = df.values.tolist()
df = pd.read_excel(address,sheet_name = 'smooth data',usecols = [3],names = None,nrows = 5000)
df_li_L_smooth = df.values.tolist()

# %%
plt.figure(dpi=100, figsize=(5,3))
plt.plot(df_li_Time_smooth,df_li_L_smooth,'-',color = 'gray')
plt.plot(x_uni,y_uni,'-',color = 'red')
plt.plot(x, y,'x',color = 'black')
plt.legend(['real result','univariateSpline','data point'])
plt.tick_params(axis='y', colors = 'white')
plt.tick_params(axis='x', colors = 'white')
plt.ylabel('Lifetime',color = 'white')
plt.xlabel('Time',color = 'white')
plt.title('N-type Silicon Heterojunction Solar Cells Degradation (393K)', color = 'white')

plt.show()
